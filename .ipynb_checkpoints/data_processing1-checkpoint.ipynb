# %%
# !pip install fancyimpute
# Out:
# ...
#     100% |████████████████████████████████| 921kB 269kB/s
# ...
#     100% |████████████████████████████████| 10.5MB 1.7MB/s
# ...
#     100% |████████████████████████████████| 317kB 2.2MB/s
# ...
#     100% |████████████████████████████████| 105.8MB 267kB/s
# ...
#     100% |████████████████████████████████| 225kB 6.2MB/s
# ...
#     100% |████████████████████████████████| 133kB 554kB/s
# ...
#     100% |████████████████████████████████| 163kB 847kB/s
# ...
#     100% |████████████████████████████████| 1.6MB 987kB/s
# ...
#     100% |████████████████████████████████| 286kB 598kB/s
# ...
#     100% |████████████████████████████████| 51kB 2.4MB/s
# ...
#     100% |████████████████████████████████| 51kB 4.4MB/s
# ...
#     100% |████████████████████████████████| 491kB 664kB/s
# ...
#     100% |████████████████████████████████| 1.4MB 709kB/s
# ...
#     100% |████████████████████████████████| 102kB 551kB/s
# ...
#     100% |████████████████████████████████| 3.2MB 906kB/s
# ...
#     100% |████████████████████████████████| 61kB 5.2MB/s
# ...

# %% [markdown]
# ### Predictive assignments

# %%
import missingno as msno
import seaborn as sns
df = sns.load_dataset('planets').copy()
df = df.select_dtypes(include=['float64', 'int64'])
df.isnull().sum()
# Out:
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
msno.matrix(df)

# %%
import pandas as pd 
import numpy as np

# %%
var_names = list(df)

# %%
var_names
# Out:
# ['number', 'orbital_period', 'mass', 'distance', 'year']

# %%
from fancyimpute import KNN

# %%
knn_imp = KNN(k=3).fit_transform(df)
# Out:
# Imputing row 1/1035 with 0 missing, elapsed time: 0.167
# Imputing row 101/1035 with 1 missing, elapsed time: 0.169
# Imputing row 201/1035 with 0 missing, elapsed time: 0.171
# Imputing row 301/1035 with 0 missing, elapsed time: 0.171
# Imputing row 401/1035 with 0 missing, elapsed time: 0.172
# Imputing row 501/1035 with 0 missing, elapsed time: 0.172
# Imputing row 601/1035 with 0 missing, elapsed time: 0.173
# Imputing row 701/1035 with 2 missing, elapsed time: 0.174
# Imputing row 801/1035 with 2 missing, elapsed time: 0.177
# Imputing row 901/1035 with 2 missing, elapsed time: 0.180
# Imputing row 1001/1035 with 1 missing, elapsed time: 0.183

# %%
df1 = pd.DataFrame(knn_imp)

# %%
df1.head()
# Out:
#      0        1      2       3       4
# 0  1.0  269.300   7.10   77.40  2006.0
# 1  1.0  874.774   2.21   56.95  2008.0
# 2  1.0  763.000   2.60   19.84  2011.0
# 3  1.0  326.030  19.40  110.62  2007.0
# 4  1.0  516.220  10.50  119.47  2009.0

# %%
df1.columns = var_names

# %%
df1.head()
# Out:
#    number  orbital_period   mass  distance    year
# 0     1.0         269.300   7.10     77.40  2006.0
# 1     1.0         874.774   2.21     56.95  2008.0
# 2     1.0         763.000   2.60     19.84  2011.0
# 3     1.0         326.030  19.40    110.62  2007.0
# 4     1.0         516.220  10.50    119.47  2009.0

# %%
df1.isnull().sum()
# Out:
# number            0
# orbital_period    0
# mass              0
# distance          0
# year              0
# dtype: int64

# %%
var_names = list(df2)

# %%
df2 = df1.copy()
df2.isnull().sum()
df2.head(20)
# Out:
#     number  orbital_period       mass  distance    year
# 0      1.0      269.300000   7.100000     77.40  2006.0
# 1      1.0      874.774000   2.210000     56.95  2008.0
# 2      1.0      763.000000   2.600000     19.84  2011.0
# 3      1.0      326.030000  19.400000    110.62  2007.0
# 4      1.0      516.220000  10.500000    119.47  2009.0
# 5      1.0      185.840000   4.800000     76.39  2008.0
# 6      1.0     1773.400000   4.640000     18.15  2002.0
# 7      1.0      798.500000   0.717753     21.41  1996.0
# 8      1.0      993.300000  10.300000     73.10  2008.0
# 9      2.0      452.800000   1.990000     74.79  2010.0
# 10     2.0      883.000000   0.860000     74.79  2010.0
# 11     1.0      335.100000   9.880000     39.43  2009.0
# 12     1.0      479.100000   3.880000     97.28  2008.0
# 13     3.0     1078.000000   2.530000     14.08  1996.0
# 14     3.0     2391.000000   0.540000     14.08  2001.0
# 15     3.0    14002.000000   1.640000     14.08  2009.0
# ...

# %%
df2[0:20] = np.NaN

# %%
df2.head(20)
# Out:
#     number  orbital_period  mass  distance  year
# 0      NaN             NaN   NaN       NaN   NaN
# 1      NaN             NaN   NaN       NaN   NaN
# 2      NaN             NaN   NaN       NaN   NaN
# 3      NaN             NaN   NaN       NaN   NaN
# 4      NaN             NaN   NaN       NaN   NaN
# 5      NaN             NaN   NaN       NaN   NaN
# 6      NaN             NaN   NaN       NaN   NaN
# 7      NaN             NaN   NaN       NaN   NaN
# 8      NaN             NaN   NaN       NaN   NaN
# 9      NaN             NaN   NaN       NaN   NaN
# 10     NaN             NaN   NaN       NaN   NaN
# 11     NaN             NaN   NaN       NaN   NaN
# 12     NaN             NaN   NaN       NaN   NaN
# 13     NaN             NaN   NaN       NaN   NaN
# 14     NaN             NaN   NaN       NaN   NaN
# 15     NaN             NaN   NaN       NaN   NaN
# 16     NaN             NaN   NaN       NaN   NaN
# 17     NaN             NaN   NaN       NaN   NaN
# ...

# %%
knn_imp = KNN(k=3).fit_transform(df)
df2_1 = pd.DataFrame(knn_imp)
df2_1.columns = var_names
# Out:
# Imputing row 1/1035 with 0 missing, elapsed time: 0.149
# Imputing row 101/1035 with 1 missing, elapsed time: 0.151
# Imputing row 201/1035 with 0 missing, elapsed time: 0.152
# Imputing row 301/1035 with 0 missing, elapsed time: 0.153
# Imputing row 401/1035 with 0 missing, elapsed time: 0.153
# Imputing row 501/1035 with 0 missing, elapsed time: 0.154
# Imputing row 601/1035 with 0 missing, elapsed time: 0.154
# Imputing row 701/1035 with 2 missing, elapsed time: 0.156
# Imputing row 801/1035 with 2 missing, elapsed time: 0.159
# Imputing row 901/1035 with 2 missing, elapsed time: 0.162
# Imputing row 1001/1035 with 1 missing, elapsed time: 0.165

# %%
df2_1.head(20)
# Out:
#     number  orbital_period       mass  distance    year
# 0      1.0      269.300000   7.100000     77.40  2006.0
# 1      1.0      874.774000   2.210000     56.95  2008.0
# 2      1.0      763.000000   2.600000     19.84  2011.0
# 3      1.0      326.030000  19.400000    110.62  2007.0
# 4      1.0      516.220000  10.500000    119.47  2009.0
# 5      1.0      185.840000   4.800000     76.39  2008.0
# 6      1.0     1773.400000   4.640000     18.15  2002.0
# 7      1.0      798.500000   0.717753     21.41  1996.0
# 8      1.0      993.300000  10.300000     73.10  2008.0
# 9      2.0      452.800000   1.990000     74.79  2010.0
# 10     2.0      883.000000   0.860000     74.79  2010.0
# 11     1.0      335.100000   9.880000     39.43  2009.0
# 12     1.0      479.100000   3.880000     97.28  2008.0
# 13     3.0     1078.000000   2.530000     14.08  1996.0
# 14     3.0     2391.000000   0.540000     14.08  2001.0
# 15     3.0    14002.000000   1.640000     14.08  2009.0
# ...
